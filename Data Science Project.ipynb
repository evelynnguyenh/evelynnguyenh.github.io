# %% [markdown]
# # **Housing Prices Across Vietnamese Cities**
#
# ---
#
#
#
# Students: Hoang Dieu Linh Nguyen, Tri Huynh
#
# Project Pages:
#
# [Project Website](https://evelynnguyenh.github.io)
#
# [Project Repository Page](https://github.com/evelynnguyenh/evelynnguyenh.github.io)

# %% [markdown]
# # **About This Project**
#
# Paragraph 1: introduce topic
#
# Paragraph 2: why this problem matters
#
# Paragraph 3: what type of data you will analyze
#
# Paragraph 4: what insights you hope to discover

# %% [markdown]
# # **Datasets and Research Questions**
#
# **Dataset 1**: House Price Prediction Dataset Vietnam - 2024
#
# Source: https://www.kaggle.com/datasets/nguyentiennhan/vietnam-housing-dataset-2024
#
# Description:
# This dataset contains information about real estate in Vietnam, including features such as property area, number of bedrooms, number of bathrooms, number of floors, furniture condition, legal status, and property price. These variables allow us to analyze how different housing characteristics influence prices and identify patterns in the housing market.
#
# Questions:

# %% [markdown]
# # **Collaboration Plan**

# %%
# Core libraries
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt

# %%
# %cd /content
# !git clone https://github.com/evelynnguyenh/evelynnguyenh.github.io.git
# Out:
# /content
# Cloning into 'evelynnguyenh.github.io'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 629.20 KiB | 2.46 MiB/s, done.

# %%
# Load the datasets
vietnam_housing = pd.read_csv('/content/evelynnguyenh.github.io/vietnam_housing_dataset.csv')
vietnam_housing.head()
# Out:
#                                              Address  Area  Frontage  \
# 0  Dự án The Empire - Vinhomes Ocean Park 2, Xã L...  84.0       NaN
# 1  Dự án The Crown - Vinhomes Ocean Park 3, Xã Ng...  60.0       NaN
# 2  Dự án The Crown - Vinhomes Ocean Park 3, Xã Ng...  90.0       6.0
# 3  Đường Nguyễn Văn Khối, Phường 11, Gò Vấp, Hồ C...  54.0       NaN
# 4   Đường Quang Trung, Phường 8, Gò Vấp, Hồ Chí Minh  92.0       NaN
#
#    Access Road House direction Balcony direction  Floors  Bedrooms  Bathrooms  \
# 0          NaN             NaN               NaN     4.0       NaN        NaN
# 1          NaN             NaN               NaN     5.0       NaN        NaN
# 2         13.0      Đông - Bắc        Đông - Bắc     5.0       NaN        NaN
# 3          3.5       Tây - Nam         Tây - Nam     2.0       2.0        3.0
# 4          NaN      Đông - Nam        Đông - Nam     2.0       4.0        4.0
#
#        Legal status Furniture state  Price
# 0  Have certificate             NaN   8.60
# 1               NaN             NaN   7.50
# 2     Sale contract             NaN   8.90
# 3  Have certificate            Full   5.35
# 4  Have certificate            Full   6.90

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
